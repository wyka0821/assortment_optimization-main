# %%
import pandas as pd

# %%
df = pd.read_csv("amazon_co-ecommerce_sample.csv")
df.head()
# Out:
#                             uniq_id  \
# 0  eac7efa5dbd3d667f26eb3d3ab504464
# 1  b17540ef7e86e461d37f3ae58b7b72ac
# 2  348f344247b0c1a935b1223072ef9d8a
# 3  e12b92dbb8eaee78b22965d2a9bbbd9f
# 4  e33a9adeed5f36840ccc227db4682a36
#
#                                         product_name manufacturer   price  \
# 0                              Hornby 2014 Catalogue       Hornby   £3.42
# 1  FunkyBuys® Large Christmas Holiday Express Fes...    FunkyBuys  £16.99
# 2  CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...          ccf   £9.99
# 3     HORNBY Coach R4410A BR Hawksworth Corridor 3rd       Hornby  £39.99
# 4  Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam...       Hornby  £32.19
#
#   number_available_in_stock number_of_reviews  number_of_answered_questions  \
# 0                     5 new                15                           1.0
# 1                       NaN                 2                           1.0
# ...

# %%
df1 = df[['product_name', 'manufacturer', 'price', 'number_of_reviews', 'average_review_rating', 'amazon_category_and_sub_category']]
df1.head()
# Out:
#                                         product_name manufacturer   price  \
# 0                              Hornby 2014 Catalogue       Hornby   £3.42
# 1  FunkyBuys® Large Christmas Holiday Express Fes...    FunkyBuys  £16.99
# 2  CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...          ccf   £9.99
# 3     HORNBY Coach R4410A BR Hawksworth Corridor 3rd       Hornby  £39.99
# 4  Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam...       Hornby  £32.19
#
#   number_of_reviews average_review_rating  \
# 0                15    4.9 out of 5 stars
# 1                 2    4.5 out of 5 stars
# 2                17    3.9 out of 5 stars
# 3                 1    5.0 out of 5 stars
# 4                 3    4.7 out of 5 stars
#
#                     amazon_category_and_sub_category
# 0  Hobbies > Model Trains & Railway Sets > Rail V...
# 1  Hobbies > Model Trains & Railway Sets > Rail V...
# 2  Hobbies > Model Trains & Railway Sets > Rail V...
# ...

# %%
df1.dropna()
# Out:
#                                            product_name  \
# 0                                 Hornby 2014 Catalogue
# 1     FunkyBuys® Large Christmas Holiday Express Fes...
# 2     CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...
# 3        HORNBY Coach R4410A BR Hawksworth Corridor 3rd
# 4     Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam...
# ...                                                 ...
# 9995  Batman 1966 TV Series Action Figures - The Rid...
# 9996  Star Wars Costume, Kids Stormtrooper Costume S...
# 9997        Defiance Lawkeeper Metal Badge Prop Replica
# 9998  Justice League of America Series 3 Green Lante...
# 9999                  Star Wars 1/72 Y-Wing Starfighter
#
#                  manufacturer   price number_of_reviews average_review_rating  \
# 0                      Hornby   £3.42                15    4.9 out of 5 stars
# 1                   FunkyBuys  £16.99                 2    4.5 out of 5 stars
# ...

# %%
df1['number_of_reviews'] = df1['number_of_reviews'].replace(regex=True, to_replace=r',', value=r'')
# Out:
# /var/folders/zp/_8jdf70d4fq1mcsnmb9rxy140000gn/T/ipykernel_1569/4247020969.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['number_of_reviews'] = df1['number_of_reviews'].replace(regex=True, to_replace=r',', value=r'')

# %%
df1 = df1.dropna()

# %%
df1
# Out:
#                                            product_name  \
# 0                                 Hornby 2014 Catalogue
# 1     FunkyBuys® Large Christmas Holiday Express Fes...
# 2     CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...
# 3        HORNBY Coach R4410A BR Hawksworth Corridor 3rd
# 4     Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam...
# ...                                                 ...
# 9995  Batman 1966 TV Series Action Figures - The Rid...
# 9996  Star Wars Costume, Kids Stormtrooper Costume S...
# 9997        Defiance Lawkeeper Metal Badge Prop Replica
# 9998  Justice League of America Series 3 Green Lante...
# 9999                  Star Wars 1/72 Y-Wing Starfighter
#
#                  manufacturer   price number_of_reviews average_review_rating  \
# 0                      Hornby   £3.42                15    4.9 out of 5 stars
# 1                   FunkyBuys  £16.99                 2    4.5 out of 5 stars
# ...

# %%
df1.number_of_reviews = pd.to_numeric(df1['number_of_reviews'])
# Out:
# /var/folders/zp/_8jdf70d4fq1mcsnmb9rxy140000gn/T/ipykernel_1569/1649833829.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.number_of_reviews = pd.to_numeric(df1['number_of_reviews'])

# %%
df1.number_of_reviews.dtypes
# Out:
# dtype('int64')

# %%
df1['price'] = df1['price'].replace(regex=True, to_replace=r'£', value=r'')
# Out:
# /var/folders/zp/_8jdf70d4fq1mcsnmb9rxy140000gn/T/ipykernel_1569/3238217312.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['price'] = df1['price'].replace(regex=True, to_replace=r'£', value=r'')

# %%
df2 = df1.drop(df1[df1['price'].str.contains(pat='-',regex=False)].index,inplace=True)  #regex=True则pat是一个正则表达式，regex=False表示pat是一个字符串
# Out:
# /var/folders/zp/_8jdf70d4fq1mcsnmb9rxy140000gn/T/ipykernel_1569/18064134.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2=df1.drop(df1[df1['price'].str.contains(pat='-',regex=False)].index,inplace=True)  #regex=True则pat是一个正则表达式，regex=False表示pat是一个字符串

# %%
df1
# Out:
#                                            product_name  \
# 0                                 Hornby 2014 Catalogue
# 1     FunkyBuys® Large Christmas Holiday Express Fes...
# 2     CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...
# 3        HORNBY Coach R4410A BR Hawksworth Corridor 3rd
# 4     Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam...
# ...                                                 ...
# 9995  Batman 1966 TV Series Action Figures - The Rid...
# 9996  Star Wars Costume, Kids Stormtrooper Costume S...
# 9997        Defiance Lawkeeper Metal Badge Prop Replica
# 9998  Justice League of America Series 3 Green Lante...
# 9999                  Star Wars 1/72 Y-Wing Starfighter
#
#                  manufacturer  price  number_of_reviews average_review_rating  \
# 0                      Hornby   3.42                 15    4.9 out of 5 stars
# 1                   FunkyBuys  16.99                  2    4.5 out of 5 stars
# ...

# %%
df1['price'] = df1['price'].replace(regex=True, to_replace=r',', value=r'')
df1['price'] = pd.to_numeric(df1['price'])
# Out:
# /var/folders/zp/_8jdf70d4fq1mcsnmb9rxy140000gn/T/ipykernel_1569/3484323738.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['price'] = df1['price'].replace(regex=True, to_replace=r',', value=r'')
# /var/folders/zp/_8jdf70d4fq1mcsnmb9rxy140000gn/T/ipykernel_1569/3484323738.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['price'] = pd.to_numeric(df1['price'])

# %%
df1
# Out:
#                                            product_name  \
# 0                                 Hornby 2014 Catalogue
# 1     FunkyBuys® Large Christmas Holiday Express Fes...
# 2     CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...
# 3        HORNBY Coach R4410A BR Hawksworth Corridor 3rd
# 4     Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam...
# ...                                                 ...
# 9995  Batman 1966 TV Series Action Figures - The Rid...
# 9996  Star Wars Costume, Kids Stormtrooper Costume S...
# 9997        Defiance Lawkeeper Metal Badge Prop Replica
# 9998  Justice League of America Series 3 Green Lante...
# 9999                  Star Wars 1/72 Y-Wing Starfighter
#
#                  manufacturer  price  number_of_reviews average_review_rating  \
# 0                      Hornby   3.42                 15    4.9 out of 5 stars
# 1                   FunkyBuys  16.99                  2    4.5 out of 5 stars
# ...

# %%
df1.price.dtypes
# Out:
# dtype('float64')

# %%
df1.average_review_rating = df1.average_review_rating.split(" ")
